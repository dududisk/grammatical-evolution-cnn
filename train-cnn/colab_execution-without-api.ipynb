# %%
#cd /content
# !git clone https://github.com/amersonchagas/mestrado-python-colab.git
# Out:
# Cloning into 'python-codes'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 53 (delta 18), reused 42 (delta 11), pack-reused 0
# Unpacking objects: 100% (53/53), done.

# %%
cd mestrado-python-colab/train-cnn/with-api
# Out:
# /content/python-codes/mestrado/python-codes/mestrado

# %%
ls -l
# Out:
# total 20
# -rw-r--r-- 1 root root 1931 Dec 16 14:54 metric.py
# -rw-r--r-- 1 root root 5667 Dec 16 14:54 model.py
# drwxr-xr-x 2 root root 4096 Dec 16 14:54 __pycache__/
# -rw-r--r-- 1 root root 1165 Dec 16 14:54 start.py

# %%
# !python start.py
# Out:
# [VERSAO] Versão do Python: 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
# [VERSAO] Versão do TensorFlow: 2.7.0
# [VERSAO] Versão do Keras: 2.7.0
# 2021-12-16 14:54:08.830654: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
#
# [STATUS] Searching new phenotype in the training queue
#
# [STATUS] Phenotype (((conv*3))*3)fc*1*64*lr-0.0001 not yet trained. Building...
#
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# ...

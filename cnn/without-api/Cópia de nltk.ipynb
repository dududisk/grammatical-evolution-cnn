# %%
# !pip install platypus-opt
# Out:
# Collecting platypus-opt
#   Downloading Platypus_Opt-1.0.4-py3-none-any.whl (70 kB)
#      |████████████████████████████████| 70 kB 3.6 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from platypus-opt) (1.15.0)
# Installing collected packages: platypus-opt
# Successfully installed platypus-opt-1.0.4

# %%
import random, copy
from platypus import Type, Mutation, Variator

class Genome(Type):

  def __init__(self, codon_size, max_codon_value):
    super(Genome, self).__init__()
    self.codon_size = codon_size
    self.max_codon_value = max_codon_value
    
  def rand(self):
    return [random.randint(0, self.max_codon_value) for i in range(self.codon_size)]

print(Genome(250, 100000))

#problem = Problem(1, 2)
#problem.types[0] = Genome(250, 100000)
#problem.directions[0] = Problem.MAXIMIZE
#problem.directions[1] = Problem.MAXIMIZE
#problem.function = evaluate
# Out:
# <__main__.Genome object at 0x7f5ab95b3bd0>

# %%
import random, copy
from platypus import Type, Mutation, Variator

class Genome(Type):

  def __init__(self, codon_size, max_codon_value):
    super(Genome, self).__init__()
    self.codon_size = codon_size
    self.max_codon_value = max_codon_value
    
  def rand(self):
    return [random.randint(0, self.max_codon_value) for i in range(self.codon_size)]





class GenomeUniformMutation(Mutation):
  
  def __init__(self, probability = 1.0):
    super(GenomeUniformMutation, self).__init__()
    self.probability = probability

  def mutate(self, parent):
    child = copy.deepcopy(parent)
    problem = child.problem
    probability = self.probability
        
    for i in range(len(child.variables)):
      if isinstance(problem.types[i], Genome):
        variable = child.variables[i]
        for j, val in enumerate(variable):
          if random.random() <= probability:
            variable[j] = random.randint(0, problem.types[i].max_codon_value)
        child.variables[i] = variable
        child.evaluated = False
    
    return child

class GenomeSinglePointCrossover(Variator):

  def __init__(self, probability = 1.0):
    super(GenomeSinglePointCrossover, self).__init__(2)
    self.probability = probability

  def evolve(self, parents):
    child1 = copy.deepcopy(parents[0])
    child2 = copy.deepcopy(parents[1])

    problem = child1.problem
    nvars = problem.nvars
      
    for i in range(nvars):
      if isinstance(problem.types[i], Genome):
        x1 = list(child1.variables[i])
        x2 = list(child2.variables[i])

        if random.random() <= self.probability:
          size = min(len(x1), len(x2))
          cxpoint = random.randint(1, size - 1)
          x1[cxpoint:], x2[cxpoint:] = x2[cxpoint:], x1[cxpoint:]
                
        child1.variables[i] = x1
        child2.variables[i] = x2
        child1.evaluated = False
        child2.evaluated = False

    return [child1, child2]

# %%
import nltk
import random, csv
from nltk import CFG
from platypus import NSGAII, SPEA2, Problem, nondominated, unique, GAOperator


# GRAMMAR = CFG.fromstring("""
#  cnn     -> blocks flatten fcs lr
#  blocks  -> block | block block | block block block
#  block   -> convs pooling
#  convs   -> conv | conv conv | conv conv conv
#  conv    -> '(Conv' bnorm '),'
#  pooling -> '(MaxPool' dropout '),' |
#  flatten -> '(Flatten),'
#  fcs     -> fc | fc fc |
#  fc      -> '(Fc ' units dropout '),'
#  bnorm   -> ' BNorm' | 
#  dropout -> ' Dropout' | 
#  lr      -> '(Lr ' rates ')'
#  rates   -> '0.1' | '0.01' | '0.001' | '0.0001'
#  units   -> '64' | '128' | '256' | '512'
# """)

GRAMMAR = CFG.fromstring("""
    cnn     -> '(' block ')' fc '*lr-' lr
    block   -> '(' conv pool ')*' m
    conv    -> '(conv*' z ')' bnorm
    pool    -> 'pool-' dropout |
    fc      -> 'fc*' k '*' units
    bnorm   -> 'bnorm-' |
    dropout -> 'dropout' |
    lr      -> '0.1' | '0.01' | '0.001' | '0.0001'
    units   -> '64' | '128' | '256' | '512'
    k       -> '0' | '1' | '2'
    z       -> '1' | '2' | '3'
    m       -> '1' | '2' | '3'
""")


def genome_to_grammar(array):
  sb = []
  stack = [GRAMMAR.start()]
  index = 0
  wraps = 0

  while stack:
    symbol = stack.pop()
    if isinstance(symbol, str):
      sb.append(symbol)
    else:
      rules = [i for i in GRAMMAR.productions() if i.lhs().symbol() == symbol.symbol()]
      rule_index = 0
      if len(rules) > 1:
        rule_index = array[index] % len(rules)
        index += 1
        if index >= len(array):
          index = 0
          wraps += 1
          if wraps > 10:
            return None
      rule = rules[rule_index]
      for production in reversed(rule.rhs()):
        stack.append(production)

  return ''.join(sb)

# from nltk.parse.generate import generate

# %%
import re, csv
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras import backend as K 
from tensorflow.keras import datasets, layers, models, callbacks, optimizers

filename = '/content/drive/MyDrive/phenotypes_eurosat.csv'

def get_metrics(phenotype):
    accuracy, accuracy_sd, f1_score, f1_score_sd = None, None, None, None
    with open(filename, mode='r') as file:
        reader = csv.reader(file)
        for row in reader:
            if row[0] == phenotype:
                accuracy = float(row[1])
                accuracy_sd = float(row[2])
                f1_score = float(row[3])
                f1_score_sd = float(row[4])
                break
    return accuracy, accuracy_sd, f1_score, f1_score_sd


def save_metrics(phenotype, accuracy, accuracy_sd, f1_score, f1_score_sd):
    with open(filename, mode='a') as file:
        writer = csv.writer(file)
        writer.writerow([phenotype, accuracy, accuracy_sd, f1_score, f1_score_sd])


# def load_dataset():

#     # (train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
#     (train_images, train_labels), (test_images, test_labels) = datasets.fashion_mnist.load_data()
    
#     train_images = train_images.reshape((train_images.shape[0], 28, 28, 1))
#     test_images = test_images.reshape((test_images.shape[0], 28, 28, 1))
    
#     validation_images, test_images, validation_labels, test_labels = train_test_split(test_images, test_labels, test_size=0.2, random_state=42)
    
#     train_images = train_images.astype("float") / 255.0
#     test_images = test_images.astype("float") / 255.0
#     validation_images = validation_images.astype("float") / 255.0

#     lb = LabelBinarizer()
#     train_labels = lb.fit_transform(train_labels)
#     validation_labels = lb.transform(validation_labels)
#     test_labels = lb.transform(test_labels)
    
#     return train_images, train_labels, test_images, test_labels, validation_images, validation_labels

def load_dataset():
    
    import tensorflow_datasets as tfds

    ds = tfds.load('eurosat', split=tfds.Split.TRAIN, batch_size=-1, shuffle_files=True)
    dsnp = tfds.as_numpy(ds)

    images = dsnp['image']
    labels = dsnp['label']

    images = images.reshape((images.shape[0], 64, 64, 3))
    images = images.astype("float") / 255.0

    train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.2, random_state=42)
    validation_images, test_images, validation_labels, test_labels = train_test_split(test_images, test_labels, test_size=0.2, random_state=42)

    lb = LabelBinarizer()

    train_labels = lb.fit_transform(train_labels)
    validation_labels = lb.transform(validation_labels)
    test_labels = lb.transform(test_labels)

    return train_images, train_labels, test_images, test_labels, validation_images, validation_labels


def build_model(phenotype):

    nconv, npool, nfc, nfcneuron = [int(i) for i in re.findall('\d+', phenotype.split('lr-')[0])]
    has_dropout = 'dropout' in phenotype
    has_batch_normalization = 'bnorm' in phenotype
    has_pool = 'pool' in phenotype
    learning_rate = float(phenotype.split('lr-')[1])

    # number of filters
    filter_size = 32

    model = models.Sequential()

    # model.add(layers.InputLayer(input_shape=(32, 32, 3)))
    # model.add(layers.InputLayer(input_shape=(28, 28, 1)))
    model.add(layers.InputLayer(input_shape=(64, 64, 3)))

    # Pooling
    for i in range(npool):

        # Convolutions
        for j in range(nconv):

            model.add(layers.Conv2D(filter_size, (3, 3), activation='relu', padding='same'))

            # Duplicate number of filters for each two convolutions
            if (((i + j) % 2) == 1): filter_size = filter_size * 2

            # Add batch normalization
            if has_batch_normalization:
                model.add(layers.BatchNormalization())

        # Add pooling
        if has_pool:
            model.add(layers.MaxPooling2D(pool_size=(2, 2)))
            # Add dropout
            if has_dropout:
                model.add(layers.Dropout(0.25))

    model.add(layers.Flatten())

    # fully connected
    for i in range(nfc):
        model.add(layers.Dense(nfcneuron))
        model.add(layers.Activation('relu'))

    if has_dropout:
        model.add(layers.Dropout(0.5))

    model.add(layers.Dense(10, activation='softmax'))

    opt = optimizers.Adam(lr=learning_rate)

    # F1 Score metric function
    def f1_score(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())
        f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
        return f1_val

    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy', f1_score])

    return model


# def build_model(phenotype):

#     model = models.Sequential()

#     filter_size = 32
#     nconvs = 0
#     optimizer = None

#     model.add(layers.InputLayer(input_shape=(32, 32, 3)))

#     for block in phenotype.split(','):
        
#         if 'Conv' in block:

#             if nconvs == 2:
#                 filter_size *= 2
#                 nconvs = 0

#             model.add(layers.Conv2D(filter_size, (3, 3), activation='relu', padding='same'))

#             if 'BNorm' in block:
#                 model.add(layers.BatchNormalization())

#             nconvs += 1
        
#         if 'MaxPool' in block:
#             model.add(layers.MaxPooling2D(pool_size=(2, 2)))
            
#             if 'Dropout' in block:
#                 model.add(layers.Dropout(0.25))

#         if 'Flatten' in block:
#             model.add(layers.Flatten())

#         if 'Fc' in block:
#             args = re.findall('\d+', block)
#             model.add(layers.Dense(int(args[0])))
#             model.add(layers.Activation('relu'))

#             if 'Dropout' in block:
#                 model.add(layers.Dropout(0.5))

#         if 'Lr' in block:
#             args = re.findall('\d+\.\d+', block)
#             optimizer = optimizers.Adam(lr=float(args[0]))


#     model.add(layers.Dense(10, activation='softmax'))

#     def f1_score(y_true, y_pred):
#         true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#         possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#         predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
#         precision = true_positives / (predicted_positives + K.epsilon())
#         recall = true_positives / (possible_positives + K.epsilon())
#         f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
#         return f1_val

#     model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', f1_score])
#     # model.summary()

#     return model


def train_model(model):

    accuracies, f1_scores = [], []

    train_images, train_labels, test_images, \
        test_labels, validation_images, validation_labels = load_dataset()

    # Train three times
    for i in range(3):

        # To free memory on google colab.
        if K.backend() == 'tensorflow':
            K.clear_session()

        print('Trainning %s of 3' % (i + 1))

        # Early Stop when bad networks are identified        
        es = callbacks.EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=10, baseline=0.5)

        model.fit(train_images, train_labels, 
                  epochs=70, 
                  batch_size=128, 
                  verbose=1,
                  validation_data=(validation_images, validation_labels), 
                  callbacks=[es])
        
        _, accuracy, f1_score = model.evaluate(test_images, test_labels, verbose=1)

        accuracies.append(accuracy)
        f1_scores.append(f1_score)

        if i == 0 and accuracy < 0.5:
            break

    return np.mean(accuracies), np.std(accuracies), np.mean(f1_scores), np.std(f1_scores)

# %%
def evaluate(variables):

    genome = variables[0]
    phenotype = genome_to_grammar(genome)

    print('PHENOTYPE:', phenotype)

    accuracy, accuracy_sd, f1_score, f1_score_sd = get_metrics(phenotype)

    if accuracy is None and f1_score is None:
        print('Phenotype not yet trained. Building...')
        model = build_model(phenotype)
        accuracy, accuracy_sd, f1_score, f1_score_sd = train_model(model)
        save_metrics(phenotype, accuracy, accuracy_sd, f1_score, f1_score_sd)

    print(accuracy, accuracy_sd, f1_score, f1_score_sd)

    return accuracy, f1_score


problem = Problem(1, 2)
problem.types[0] = Genome(250, 100000)
problem.directions[0] = Problem.MAXIMIZE
problem.directions[1] = Problem.MAXIMIZE
problem.function = evaluate

operator = GAOperator(GenomeSinglePointCrossover(probability=0.75), GenomeUniformMutation(probability=0.01))

algorithm = NSGAII(problem, population_size=50, variator=operator)
# algorithm = SPEA2(problem, population_size=50, variator=operator)

num_generations = 30
max_accuracy, max_fscore = [0] * num_generations, [0] * num_generations

for i in range(num_generations):
  print('Geração:', i + 1)
  algorithm.step()
  for solution in unique(nondominated(algorithm.result)):
    genome = solution.variables[0]
    phenotype = genome_to_grammar(genome)
    print(phenotype, solution.objectives)
    if solution.objectives[0] > max_accuracy[i]:
      max_accuracy[i] = solution.objectives[0]
    if solution.objectives[1] > max_fscore[i]:
      max_fscore[i] = solution.objectives[1]
# Out:
# Geração: 1
# PHENOTYPE: (((conv*1))*2)fc*1*256*lr-0.01
# Phenotype not yet trained. Building...
# Trainning 1 of 3
# Epoch 1/70
# 169/169 [==============================] - 39s 36ms/step - loss: 11.1216 - accuracy: 0.1123 - f1_score: 0.0053 - val_loss: 2.2992 - val_accuracy: 0.1030 - val_f1_score: 0.0000e+00
# Epoch 2/70
# 169/169 [==============================] - 5s 30ms/step - loss: 2.2961 - accuracy: 0.1092 - f1_score: 0.0000e+00 - val_loss: 2.2991 - val_accuracy: 0.1030 - val_f1_score: 0.0000e+00
# Epoch 3/70
# 169/169 [==============================] - 5s 30ms/step - loss: 2.2954 - accuracy: 0.1153 - f1_score: 0.0000e+00 - val_loss: 2.2978 - val_accuracy: 0.1146 - val_f1_score: 0.0000e+00
# Epoch 4/70
# 169/169 [==============================] - 5s 30ms/step - loss: 2.2950 - accuracy: 0.1104 - f1_score: 0.0000e+00 - val_loss: 2.2984 - val_accuracy: 0.1046 - val_f1_score: 0.0000e+00
# Epoch 5/70
# 169/169 [==============================] - 5s 30ms/step - loss: 2.2948 - accuracy: 0.1144 - f1_score: 0.0000e+00 - val_loss: 2.2978 - val_accuracy: 0.1046 - val_f1_score: 0.0000e+00
# Epoch 6/70
# 169/169 [==============================] - 5s 30ms/step - loss: 2.2962 - accuracy: 0.1110 - f1_score: 0.0000e+00 - val_loss: 2.2986 - val_accuracy: 0.1197 - val_f1_score: 0.0000e+00
# Epoch 7/70
# 169/169 [==============================] - 5s 31ms/step - loss: 2.2958 - accuracy: 0.1108 - f1_score: 0.0000e+00 - val_loss: 2.2985 - val_accuracy: 0.1030 - val_f1_score: 0.0000e+00
# Epoch 8/70
# 169/169 [==============================] - 5s 30ms/step - loss: 2.2964 - accuracy: 0.1069 - f1_score: 0.0000e+00 - val_loss: 2.2977 - val_accuracy: 0.1046 - val_f1_score: 0.0000e+00
# Epoch 9/70
# 169/169 [==============================] - 5s 30ms/step - loss: 2.2947 - accuracy: 0.1111 - f1_score: 0.0000e+00 - val_loss: 2.2971 - val_accuracy: 0.1030 - val_f1_score: 0.0000e+00
# Epoch 10/70
# 169/169 [==============================] - 5s 30ms/step - loss: 2.2956 - accuracy: 0.1116 - f1_score: 0.0000e+00 - val_loss: 2.2975 - val_accuracy: 0.1046 - val_f1_score: 0.0000e+00
# Epoch 00010: early stopping
# 34/34 [==============================] - 0s 6ms/step - loss: 2.2923 - accuracy: 0.0963 - f1_score: 0.0000e+00
# 0.0962962955236435 0.0 0.0 0.0
# PHENOTYPE: (((conv*3)bnorm-)*1)fc*2*256*lr-0.01
# Phenotype not yet trained. Building...
# Trainning 1 of 3
# Epoch 1/70
# 169/169 [==============================] - 14s 75ms/step - loss: 157.7476 - accuracy: 0.1789 - f1_score: 0.1445 - val_loss: 5.0635 - val_accuracy: 0.1104 - val_f1_score: 0.0212
# Epoch 2/70
# 169/169 [==============================] - 12s 71ms/step - loss: 2.1880 - accuracy: 0.1664 - f1_score: 0.0908 - val_loss: 2.8706 - val_accuracy: 0.1625 - val_f1_score: 0.0918
# Epoch 3/70
# 169/169 [==============================] - 12s 72ms/step - loss: 2.2239 - accuracy: 0.1745 - f1_score: 0.0937 - val_loss: 2.1847 - val_accuracy: 0.1650 - val_f1_score: 0.0850
# Epoch 4/70
# 169/169 [==============================] - 12s 72ms/step - loss: 2.0809 - accuracy: 0.1977 - f1_score: 0.1167 - val_loss: 1.9895 - val_accuracy: 0.1956 - val_f1_score: 0.1286
# Epoch 5/70
# 169/169 [==============================] - 12s 73ms/step - loss: 2.0202 - accuracy: 0.2173 - f1_score: 0.1460 - val_loss: 2.0237 - val_accuracy: 0.2113 - val_f1_score: 0.1377
# Epoch 6/70
# 169/169 [==============================] - 12s 73ms/step - loss: 1.9597 - accuracy: 0.2426 - f1_score: 0.1881 - val_loss: 2.9776 - val_accuracy: 0.1907 - val_f1_score: 0.1423
# Epoch 7/70
# 169/169 [==============================] - 12s 74ms/step - loss: 2.1016 - accuracy: 0.2005 - f1_score: 0.1391 - val_loss: 2.0655 - val_accuracy: 0.3102 - val_f1_score: 0.2647
# Epoch 8/70
# 169/169 [==============================] - 12s 74ms/step - loss: 1.9425 - accuracy: 0.2615 - f1_score: 0.2044 - val_loss: 2.2138 - val_accuracy: 0.1965 - val_f1_score: 0.1438
# Epoch 9/70
# 169/169 [==============================] - 13s 74ms/step - loss: 1.9901 - accuracy: 0.2320 - f1_score: 0.1537 - val_loss: 1.9404 - val_accuracy: 0.2632 - val_f1_score: 0.1670
# Epoch 10/70
# 169/169 [==============================] - 13s 74ms/step - loss: 2.0009 - accuracy: 0.2373 - f1_score: 0.1362 - val_loss: 2.4309 - val_accuracy: 0.1072 - val_f1_score: 0.0024
# Epoch 00010: early stopping
# 34/34 [==============================] - 0s 8ms/step - loss: 2.4604 - accuracy: 0.1259 - f1_score: 0.0000e+00
# 0.1259259283542633 0.0 0.0 0.0
# PHENOTYPE: (((conv*2)bnorm-)*2)fc*0*512*lr-0.1
# Phenotype not yet trained. Building...
# Trainning 1 of 3
# Epoch 1/70
# 169/169 [==============================] - 23s 124ms/step - loss: 2718.6397 - accuracy: 0.2710 - f1_score: 0.2692 - val_loss: 1507.7168 - val_accuracy: 0.1507 - val_f1_score: 0.1503
# Epoch 2/70
# 169/169 [==============================] - 20s 116ms/step - loss: 68.4250 - accuracy: 0.3676 - f1_score: 0.3675 - val_loss: 23.4470 - val_accuracy: 0.4238 - val_f1_score: 0.4241
# Epoch 3/70
# 169/169 [==============================] - 20s 119ms/step - loss: 13.0141 - accuracy: 0.3973 - f1_score: 0.3970 - val_loss: 10.7687 - val_accuracy: 0.3394 - val_f1_score: 0.3395
# Epoch 4/70
# 169/169 [==============================] - 20s 116ms/step - loss: 10.2981 - accuracy: 0.4183 - f1_score: 0.4186 - val_loss: 142.2504 - val_accuracy: 0.2861 - val_f1_score: 0.2862
# Epoch 5/70
# 169/169 [==============================] - 20s 116ms/step - loss: 1104.7104 - accuracy: 0.3105 - f1_score: 0.3105 - val_loss: 1904206.1250 - val_accuracy: 0.0938 - val_f1_score: 0.0941
# Epoch 6/70
# 169/169 [==============================] - 20s 116ms/step - loss: 1121.0904 - accuracy: 0.2644 - f1_score: 0.2644 - val_loss: 837.4204 - val_accuracy: 0.1287 - val_f1_score: 0.1289
# Epoch 7/70
# 169/169 [==============================] - 20s 116ms/step - loss: 54.6120 - accuracy: 0.3297 - f1_score: 0.3297 - val_loss: 43.6684 - val_accuracy: 0.2558 - val_f1_score: 0.2557
# Epoch 8/70
# 169/169 [==============================] - 20s 116ms/step - loss: 19.7684 - accuracy: 0.2756 - f1_score: 0.2749 - val_loss: 4.9667 - val_accuracy: 0.2535 - val_f1_score: 0.2461
# Epoch 9/70
# 169/169 [==============================] - 20s 116ms/step - loss: 3.2368 - accuracy: 0.3055 - f1_score: 0.2886 - val_loss: 2.4797 - val_accuracy: 0.3493 - val_f1_score: 0.3186
# Epoch 10/70
# 169/169 [==============================] - 20s 116ms/step - loss: 3.2439 - accuracy: 0.3255 - f1_score: 0.3054 - val_loss: 2.8334 - val_accuracy: 0.3072 - val_f1_score: 0.2939
# Epoch 00010: early stopping
# 34/34 [==============================] - 1s 15ms/step - loss: 2.7342 - accuracy: 0.3241 - f1_score: 0.3053
# 0.32407405972480774 0.0 0.30527350306510925 0.0
# PHENOTYPE: (((conv*1)pool-dropout)*2)fc*1*256*lr-0.0001
# 0.8179012338320414 0.021186429532675723 0.8194811145464579 0.02095631380206305
# PHENOTYPE: (((conv*2)bnorm-)*2)fc*1*256*lr-0.001
# Phenotype not yet trained. Building...
# Trainning 1 of 3
# Epoch 1/70
# 169/169 [==============================] - 28s 164ms/step - loss: 21.7133 - accuracy: 0.3908 - f1_score: 0.3818 - val_loss: 42.1710 - val_accuracy: 0.1148 - val_f1_score: 0.1151
# Epoch 2/70
# 169/169 [==============================] - 28s 163ms/step - loss: 1.5746 - accuracy: 0.4564 - f1_score: 0.4546 - val_loss: 57.1569 - val_accuracy: 0.1197 - val_f1_score: 0.1192
# Epoch 3/70
# 169/169 [==============================] - 27s 161ms/step - loss: 1.4044 - accuracy: 0.5072 - f1_score: 0.5072 - val_loss: 12.0152 - val_accuracy: 0.1981 - val_f1_score: 0.2084
# Epoch 4/70
# 169/169 [==============================] - 27s 163ms/step - loss: 1.1895 - accuracy: 0.5977 - f1_score: 0.5866 - val_loss: 1.3487 - val_accuracy: 0.5431 - val_f1_score: 0.5292
# Epoch 5/70
# 169/169 [==============================] - 28s 163ms/step - loss: 1.0910 - accuracy: 0.6069 - f1_score: 0.6100 - val_loss: 1.3227 - val_accuracy: 0.6000 - val_f1_score: 0.5617
# Epoch 6/70
# 169/169 [==============================] - 28s 163ms/step - loss: 1.1815 - accuracy: 0.5859 - f1_score: 0.5637 - val_loss: 1.4837 - val_accuracy: 0.5525 - val_f1_score: 0.5373
# Epoch 7/70
# 169/169 [==============================] - 28s 163ms/step - loss: 0.9113 - accuracy: 0.6538 - f1_score: 0.6460 - val_loss: 1.3883 - val_accuracy: 0.5588 - val_f1_score: 0.5206
# Epoch 8/70
# 169/169 [==============================] - 27s 163ms/step - loss: 0.8257 - accuracy: 0.6805 - f1_score: 0.6620 - val_loss: 1.2249 - val_accuracy: 0.6273 - val_f1_score: 0.6286
# Epoch 9/70
# 169/169 [==============================] - 28s 163ms/step - loss: 0.7199 - accuracy: 0.7194 - f1_score: 0.6893 - val_loss: 1.5689 - val_accuracy: 0.5854 - val_f1_score: 0.5666
# Epoch 10/70
# 169/169 [==============================] - 28s 163ms/step - loss: 0.6362 - accuracy: 0.7468 - f1_score: 0.7272 - val_loss: 1.3055 - val_accuracy: 0.6176 - val_f1_score: 0.5807
# Epoch 11/70
# 169/169 [==============================] - 28s 164ms/step - loss: 0.5810 - accuracy: 0.7832 - f1_score: 0.7519 - val_loss: 1.1546 - val_accuracy: 0.6725 - val_f1_score: 0.6693
# Epoch 12/70
# 169/169 [==============================] - 28s 164ms/step - loss: 0.4584 - accuracy: 0.8431 - f1_score: 0.8290 - val_loss: 1.3445 - val_accuracy: 0.7157 - val_f1_score: 0.7028
# Epoch 13/70
# 169/169 [==============================] - 28s 164ms/step - loss: 0.3548 - accuracy: 0.8807 - f1_score: 0.8681 - val_loss: 1.2475 - val_accuracy: 0.7354 - val_f1_score: 0.7304
# Epoch 14/70
# 169/169 [==============================] - 28s 164ms/step - loss: 0.2906 - accuracy: 0.8966 - f1_score: 0.8904 - val_loss: 2.5435 - val_accuracy: 0.5877 - val_f1_score: 0.5941
# Epoch 15/70
# 169/169 [==============================] - 28s 164ms/step - loss: 0.2422 - accuracy: 0.9170 - f1_score: 0.9147 - val_loss: 1.7625 - val_accuracy: 0.6398 - val_f1_score: 0.6390
# Epoch 16/70
# 169/169 [==============================] - 28s 164ms/step - loss: 0.2360 - accuracy: 0.9240 - f1_score: 0.9207 - val_loss: 1.5707 - val_accuracy: 0.7118 - val_f1_score: 0.7057
# Epoch 17/70
# 169/169 [==============================] - 28s 164ms/step - loss: 0.1935 - accuracy: 0.9375 - f1_score: 0.9363 - val_loss: 1.3495 - val_accuracy: 0.7326 - val_f1_score: 0.7290
# Epoch 18/70
# 169/169 [==============================] - 28s 164ms/step - loss: 0.1646 - accuracy: 0.9500 - f1_score: 0.9495 - val_loss: 2.2781 - val_accuracy: 0.6581 - val_f1_score: 0.6573
# Epoch 19/70
# 169/169 [==============================] - 28s 164ms/step - loss: 0.2428 - accuracy: 0.9300 - f1_score: 0.9247 - val_loss: 2.2972 - val_accuracy: 0.5822 - val_f1_score: 0.5828
# Epoch 20/70
# 169/169 [==============================] - 28s 164ms/step - loss: 0.2000 - accuracy: 0.9413 - f1_score: 0.9370 - val_loss: 1.1284 - val_accuracy: 0.7727 - val_f1_score: 0.7661
# Epoch 21/70
# 169/169 [==============================] - 28s 164ms/step - loss: 0.1372 - accuracy: 0.9567 - f1_score: 0.9540 - val_loss: 1.3234 - val_accuracy: 0.7542 - val_f1_score: 0.7531
# Epoch 22/70
# 169/169 [==============================] - 28s 163ms/step - loss: 0.1933 - accuracy: 0.9434 - f1_score: 0.9423 - val_loss: 5.6766 - val_accuracy: 0.4484 - val_f1_score: 0.4459
# Epoch 23/70
# 169/169 [==============================] - 28s 163ms/step - loss: 0.3358 - accuracy: 0.9332 - f1_score: 0.9327 - val_loss: 1.4733 - val_accuracy: 0.7463 - val_f1_score: 0.7502
# Epoch 24/70
# 169/169 [==============================] - 28s 163ms/step - loss: 0.1470 - accuracy: 0.9562 - f1_score: 0.9560 - val_loss: 1.0822 - val_accuracy: 0.7655 - val_f1_score: 0.7703
# Epoch 25/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.1230 - accuracy: 0.9594 - f1_score: 0.9601 - val_loss: 1.6454 - val_accuracy: 0.7361 - val_f1_score: 0.7382
# Epoch 26/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.1030 - accuracy: 0.9686 - f1_score: 0.9681 - val_loss: 2.4351 - val_accuracy: 0.6488 - val_f1_score: 0.6506
# Epoch 27/70
# 169/169 [==============================] - 27s 163ms/step - loss: 0.1209 - accuracy: 0.9665 - f1_score: 0.9665 - val_loss: 1.6624 - val_accuracy: 0.7493 - val_f1_score: 0.7505
# Epoch 28/70
# 169/169 [==============================] - 27s 163ms/step - loss: 0.1155 - accuracy: 0.9671 - f1_score: 0.9672 - val_loss: 1.6451 - val_accuracy: 0.7208 - val_f1_score: 0.7222
# Epoch 29/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.1138 - accuracy: 0.9661 - f1_score: 0.9660 - val_loss: 1.3880 - val_accuracy: 0.7597 - val_f1_score: 0.7623
# Epoch 30/70
# 169/169 [==============================] - 27s 163ms/step - loss: 0.1299 - accuracy: 0.9608 - f1_score: 0.9608 - val_loss: 2.1530 - val_accuracy: 0.7134 - val_f1_score: 0.7144
# Epoch 00030: early stopping
# 34/34 [==============================] - 0s 12ms/step - loss: 2.1480 - accuracy: 0.7130 - f1_score: 0.7145
# Trainning 2 of 3
# Epoch 1/70
# 169/169 [==============================] - 28s 164ms/step - loss: 0.1428 - accuracy: 0.9631 - f1_score: 0.9630 - val_loss: 2.2055 - val_accuracy: 0.6773 - val_f1_score: 0.6778
# Epoch 2/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.1543 - accuracy: 0.9594 - f1_score: 0.9592 - val_loss: 8.3704 - val_accuracy: 0.3505 - val_f1_score: 0.3487
# Epoch 3/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.1376 - accuracy: 0.9591 - f1_score: 0.9593 - val_loss: 1.6706 - val_accuracy: 0.7306 - val_f1_score: 0.7331
# Epoch 4/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.1049 - accuracy: 0.9691 - f1_score: 0.9690 - val_loss: 3.2713 - val_accuracy: 0.6292 - val_f1_score: 0.6289
# Epoch 5/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.2054 - accuracy: 0.9425 - f1_score: 0.9425 - val_loss: 8.8944 - val_accuracy: 0.6463 - val_f1_score: 0.6453
# Epoch 6/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.2534 - accuracy: 0.9300 - f1_score: 0.9304 - val_loss: 2.0284 - val_accuracy: 0.6674 - val_f1_score: 0.6675
# Epoch 7/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.1228 - accuracy: 0.9642 - f1_score: 0.9641 - val_loss: 3.3474 - val_accuracy: 0.6403 - val_f1_score: 0.6404
# Epoch 8/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.0913 - accuracy: 0.9744 - f1_score: 0.9742 - val_loss: 1.3993 - val_accuracy: 0.7565 - val_f1_score: 0.7553
# Epoch 9/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.0644 - accuracy: 0.9821 - f1_score: 0.9820 - val_loss: 1.2576 - val_accuracy: 0.7819 - val_f1_score: 0.7823
# Epoch 10/70
# 169/169 [==============================] - 27s 163ms/step - loss: 0.0586 - accuracy: 0.9836 - f1_score: 0.9834 - val_loss: 1.8531 - val_accuracy: 0.7528 - val_f1_score: 0.7530
# Epoch 11/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.0712 - accuracy: 0.9819 - f1_score: 0.9819 - val_loss: 4.7078 - val_accuracy: 0.5076 - val_f1_score: 0.5112
# Epoch 12/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.0605 - accuracy: 0.9844 - f1_score: 0.9843 - val_loss: 1.6064 - val_accuracy: 0.7546 - val_f1_score: 0.7568
# Epoch 13/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.0534 - accuracy: 0.9860 - f1_score: 0.9859 - val_loss: 1.7265 - val_accuracy: 0.7806 - val_f1_score: 0.7813
# Epoch 14/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.1131 - accuracy: 0.9712 - f1_score: 0.9716 - val_loss: 2.6770 - val_accuracy: 0.6403 - val_f1_score: 0.6404
# Epoch 15/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.0699 - accuracy: 0.9821 - f1_score: 0.9822 - val_loss: 1.9827 - val_accuracy: 0.6711 - val_f1_score: 0.6729
# Epoch 16/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.0562 - accuracy: 0.9857 - f1_score: 0.9857 - val_loss: 1.4745 - val_accuracy: 0.7822 - val_f1_score: 0.7846
# Epoch 17/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.0803 - accuracy: 0.9800 - f1_score: 0.9798 - val_loss: 1.7457 - val_accuracy: 0.7463 - val_f1_score: 0.7465
# Epoch 18/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.0992 - accuracy: 0.9755 - f1_score: 0.9755 - val_loss: 1.6887 - val_accuracy: 0.7294 - val_f1_score: 0.7314
# Epoch 19/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.0672 - accuracy: 0.9831 - f1_score: 0.9831 - val_loss: 3.0943 - val_accuracy: 0.6266 - val_f1_score: 0.6281
# Epoch 20/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.0477 - accuracy: 0.9882 - f1_score: 0.9884 - val_loss: 1.4833 - val_accuracy: 0.7722 - val_f1_score: 0.7733
# Epoch 21/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0629 - accuracy: 0.9848 - f1_score: 0.9847 - val_loss: 3.8695 - val_accuracy: 0.4653 - val_f1_score: 0.4684
# Epoch 22/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.1619 - accuracy: 0.9589 - f1_score: 0.9594 - val_loss: 2.9106 - val_accuracy: 0.6127 - val_f1_score: 0.6146
# Epoch 23/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0664 - accuracy: 0.9830 - f1_score: 0.9831 - val_loss: 1.3867 - val_accuracy: 0.7694 - val_f1_score: 0.7695
# Epoch 24/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0414 - accuracy: 0.9899 - f1_score: 0.9900 - val_loss: 2.1463 - val_accuracy: 0.7542 - val_f1_score: 0.7545
# Epoch 25/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0380 - accuracy: 0.9905 - f1_score: 0.9905 - val_loss: 2.1107 - val_accuracy: 0.7282 - val_f1_score: 0.7294
# Epoch 26/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0390 - accuracy: 0.9907 - f1_score: 0.9908 - val_loss: 1.4428 - val_accuracy: 0.7921 - val_f1_score: 0.7923
# Epoch 27/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0354 - accuracy: 0.9913 - f1_score: 0.9913 - val_loss: 1.6493 - val_accuracy: 0.7778 - val_f1_score: 0.7785
# Epoch 28/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0359 - accuracy: 0.9910 - f1_score: 0.9910 - val_loss: 1.6124 - val_accuracy: 0.8021 - val_f1_score: 0.8020
# Epoch 29/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0327 - accuracy: 0.9911 - f1_score: 0.9912 - val_loss: 1.6342 - val_accuracy: 0.7889 - val_f1_score: 0.7909
# Epoch 30/70
# 169/169 [==============================] - 27s 162ms/step - loss: 0.0309 - accuracy: 0.9911 - f1_score: 0.9912 - val_loss: 1.4999 - val_accuracy: 0.7896 - val_f1_score: 0.7916
# Epoch 31/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0559 - accuracy: 0.9851 - f1_score: 0.9853 - val_loss: 8.6557 - val_accuracy: 0.4558 - val_f1_score: 0.4559
# Epoch 32/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.5576 - accuracy: 0.8867 - f1_score: 0.8871 - val_loss: 1.4730 - val_accuracy: 0.7215 - val_f1_score: 0.7229
# Epoch 33/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0853 - accuracy: 0.9774 - f1_score: 0.9776 - val_loss: 1.4530 - val_accuracy: 0.7389 - val_f1_score: 0.7409
# Epoch 34/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0526 - accuracy: 0.9886 - f1_score: 0.9886 - val_loss: 1.3568 - val_accuracy: 0.7799 - val_f1_score: 0.7809
# Epoch 35/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0476 - accuracy: 0.9892 - f1_score: 0.9895 - val_loss: 1.6569 - val_accuracy: 0.7641 - val_f1_score: 0.7654
# Epoch 36/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0357 - accuracy: 0.9908 - f1_score: 0.9909 - val_loss: 1.5540 - val_accuracy: 0.7745 - val_f1_score: 0.7754
# Epoch 37/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0321 - accuracy: 0.9913 - f1_score: 0.9914 - val_loss: 1.4256 - val_accuracy: 0.7829 - val_f1_score: 0.7853
# Epoch 38/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0358 - accuracy: 0.9912 - f1_score: 0.9912 - val_loss: 2.3241 - val_accuracy: 0.6995 - val_f1_score: 0.7029
# Epoch 00038: early stopping
# 34/34 [==============================] - 0s 12ms/step - loss: 2.5470 - accuracy: 0.7074 - f1_score: 0.7109
# Trainning 3 of 3
# Epoch 1/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0337 - accuracy: 0.9908 - f1_score: 0.9909 - val_loss: 1.6643 - val_accuracy: 0.7852 - val_f1_score: 0.7848
# Epoch 2/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0280 - accuracy: 0.9926 - f1_score: 0.9926 - val_loss: 1.5790 - val_accuracy: 0.8007 - val_f1_score: 0.8014
# Epoch 3/70
# 169/169 [==============================] - 27s 160ms/step - loss: 0.0279 - accuracy: 0.9922 - f1_score: 0.9922 - val_loss: 1.4100 - val_accuracy: 0.7981 - val_f1_score: 0.7988
# Epoch 4/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0287 - accuracy: 0.9916 - f1_score: 0.9917 - val_loss: 1.8058 - val_accuracy: 0.7729 - val_f1_score: 0.7740
# Epoch 5/70
# 169/169 [==============================] - 27s 160ms/step - loss: 0.0482 - accuracy: 0.9874 - f1_score: 0.9874 - val_loss: 1.9024 - val_accuracy: 0.7627 - val_f1_score: 0.7633
# Epoch 6/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0610 - accuracy: 0.9849 - f1_score: 0.9848 - val_loss: 8.1730 - val_accuracy: 0.4706 - val_f1_score: 0.4709
# Epoch 7/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0635 - accuracy: 0.9844 - f1_score: 0.9847 - val_loss: 1.5731 - val_accuracy: 0.7715 - val_f1_score: 0.7734
# Epoch 8/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0509 - accuracy: 0.9892 - f1_score: 0.9892 - val_loss: 1.8702 - val_accuracy: 0.7731 - val_f1_score: 0.7737
# Epoch 9/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0351 - accuracy: 0.9918 - f1_score: 0.9918 - val_loss: 1.8114 - val_accuracy: 0.7766 - val_f1_score: 0.7781
# Epoch 10/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0287 - accuracy: 0.9922 - f1_score: 0.9921 - val_loss: 1.7013 - val_accuracy: 0.7826 - val_f1_score: 0.7836
# Epoch 11/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0345 - accuracy: 0.9919 - f1_score: 0.9919 - val_loss: 1.6606 - val_accuracy: 0.7866 - val_f1_score: 0.7881
# Epoch 12/70
# 169/169 [==============================] - 27s 161ms/step - loss: 0.0334 - accuracy: 0.9913 - f1_score: 0.9915 - val_loss: 1.7752 - val_accuracy: 0.7715 - val_f1_score: 0.7724
# Epoch 00012: early stopping
# 34/34 [==============================] - 0s 12ms/step - loss: 1.9543 - accuracy: 0.7630 - f1_score: 0.7615
# 0.7277777791023254 0.02498282891383018 0.7289488712946574 0.023051233046099982
# PHENOTYPE: (((conv*3)bnorm-)*2)fc*0*64*lr-0.1
# Phenotype not yet trained. Building...

# %%
import matplotlib.pyplot as plt

plt.plot(max_accuracy, label = 'Acurácia')
plt.plot(max_fscore, label = 'F1Score')
plt.xlabel('Geração')
plt.ylabel('Valor')
plt.legend()
plt.show()
